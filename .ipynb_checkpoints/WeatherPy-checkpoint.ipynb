# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime

# Import API key
from api_keys import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

now = datetime.datetime.now()

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units ="imperial"

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=538bc5daa706ecba0731d72f005b5809&units=imperial&q=

# %%
city = []
cloudiness= []
country= []
date= []
humidity= []
max_temp= []
wind_speed= []
foundcities= []
foundlat= []
foundlong= []

citycount = 1
citycountlimit = 500

for city in cities:
    
    if citycount == citycountlimit + 1:
        print("stop at limit")
        break
    try:
        response = requests.get(query_url + city).json()
    
        
        cod = response.get("cod") 

        if cod == 200:

            #Get temperature (F) , Humidity (%), Cloudiness (%), WindSpeed (mph)

            #print(response)
            print(f"Processing Record {citycount} of {citycountlimit} for City: {city}")

            '''
            print(f"The city information received is: {city}")
            print(f"The cloudiness information received is: {response['clouds']['all']}")
            print(f"The country information received is: {response['sys']['country']}")
            print(f"The date information received is: {response['dt']}")
            print(f"The humidity information received is: {response['main']['humidity']}")
            print(f"The max_temp information received is: {response['main']['temp_max']}")
            print(f"The wind_speed information received is: {response['wind']['speed']}")
            print(f"The lat information received is: {response['coord']['lat']}")
            print(f"The long information received is: {response['coord']['lon']}")
            print("-----------------------")
            '''
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])


            foundcities.append(response['name'])    #now grabbing from openweather, where cap is ok
            foundlat.append(response['coord']['lat'])
            foundlong.append(response['coord']['lon'])

              
            '''
            print(f"The city information list is now: {foundcities}")
            print(f"The cloudiness information list is now: {cloudiness}")
            print(f"The country information list is now: {country}")
            print(f"The date information list is now: {date}")
            print(f"The humidity information list is now: {humidity}")
            print(f"The max_temp information list is now {max_temp}")
            print(f"The wind_speed information list is now: {wind_speed}")
            print(f"The lat information list is now {foundlat}")
            print(f"The long information list is now: {foundlong}")
            '''

            #break     #review our data

            citycount = citycount + 1

        else:
            print(f"No weather data found for this city: {city}, weather server response code:{cod}")
            pass
            
    except Exception as e:
        pass
# Out:
# Processing Record 1 of 500 for City: severo-kurilsk
# Processing Record 2 of 500 for City: barrow
# Processing Record 3 of 500 for City: nanortalik
# Processing Record 4 of 500 for City: predesti
# Processing Record 5 of 500 for City: kichera
# Processing Record 6 of 500 for City: ialibu
# Processing Record 7 of 500 for City: hermanus
# Processing Record 8 of 500 for City: busselton
# Processing Record 9 of 500 for City: vaini
# Processing Record 10 of 500 for City: khash
# Processing Record 11 of 500 for City: bluff
# Processing Record 12 of 500 for City: pinawa
# Processing Record 13 of 500 for City: nishihara
# Processing Record 14 of 500 for City: kitaibaraki
# Processing Record 15 of 500 for City: jamestown
# Processing Record 16 of 500 for City: rampur
# Processing Record 17 of 500 for City: punta arenas
# Processing Record 18 of 500 for City: east london
# Processing Record 19 of 500 for City: albany
# Processing Record 20 of 500 for City: richards bay
# Processing Record 21 of 500 for City: avarua
# Processing Record 22 of 500 for City: victoria
# Processing Record 23 of 500 for City: rawson
# Processing Record 24 of 500 for City: charleville-mezieres
# Processing Record 25 of 500 for City: jantetelco
# Processing Record 26 of 500 for City: shihezi
# No weather data found for this city: urumqi, weather server response code:404
# Processing Record 27 of 500 for City: khatanga
# Processing Record 28 of 500 for City: maloy
# Processing Record 29 of 500 for City: rikitea
# No weather data found for this city: mys shmidta, weather server response code:404
# No weather data found for this city: tabiauea, weather server response code:404
# Processing Record 30 of 500 for City: butaritari
# Processing Record 31 of 500 for City: araouane
# Processing Record 32 of 500 for City: mahibadhoo
# Processing Record 33 of 500 for City: constitucion
# Processing Record 34 of 500 for City: guerrero negro
# Processing Record 35 of 500 for City: ushuaia
# Processing Record 36 of 500 for City: mataura
# Processing Record 37 of 500 for City: nhulunbuy
# Processing Record 38 of 500 for City: yamada
# Processing Record 39 of 500 for City: qaanaaq
# Processing Record 40 of 500 for City: venado tuerto
# Processing Record 41 of 500 for City: leningradskiy
# Processing Record 42 of 500 for City: ponta do sol
# Processing Record 43 of 500 for City: north bend
# No weather data found for this city: illoqqortoormiut, weather server response code:404
# Processing Record 44 of 500 for City: kawalu
# Processing Record 45 of 500 for City: bredasdorp
# Processing Record 46 of 500 for City: cape town
# Processing Record 47 of 500 for City: port elizabeth
# Processing Record 48 of 500 for City: dikson
# Processing Record 49 of 500 for City: general pico
# Processing Record 50 of 500 for City: afua
# No weather data found for this city: barentsburg, weather server response code:404
# Processing Record 51 of 500 for City: kolokani
# Processing Record 52 of 500 for City: dossor
# Processing Record 53 of 500 for City: margate
# No weather data found for this city: belushya guba, weather server response code:404
# Processing Record 54 of 500 for City: dalby
# Processing Record 55 of 500 for City: tiksi
# Processing Record 56 of 500 for City: faya
# Processing Record 57 of 500 for City: saint-philippe
# Processing Record 58 of 500 for City: kirakira
# Processing Record 59 of 500 for City: college
# Processing Record 60 of 500 for City: san quintin
# Processing Record 61 of 500 for City: hasaki
# Processing Record 62 of 500 for City: reguengos de monsaraz
# Processing Record 63 of 500 for City: uhlove
# Processing Record 64 of 500 for City: ankang
# No weather data found for this city: cozumel, weather server response code:404
# Processing Record 65 of 500 for City: havre-saint-pierre
# Processing Record 66 of 500 for City: sao filipe
# Processing Record 67 of 500 for City: chapada dos guimaraes
# Processing Record 68 of 500 for City: namibe
# Processing Record 69 of 500 for City: kardymovo
# No weather data found for this city: taolanaro, weather server response code:404
# Processing Record 70 of 500 for City: simiti
# Processing Record 71 of 500 for City: kapaa
# No weather data found for this city: vaitupu, weather server response code:404
# Processing Record 72 of 500 for City: ribeira grande
# Processing Record 73 of 500 for City: komsomolskiy
# Processing Record 74 of 500 for City: karratha
# Processing Record 75 of 500 for City: preobrazheniye
# No weather data found for this city: angra, weather server response code:404
# Processing Record 76 of 500 for City: buraydah
# Processing Record 77 of 500 for City: port alfred
# Processing Record 78 of 500 for City: placido de castro
# Processing Record 79 of 500 for City: hobart
# Processing Record 80 of 500 for City: bilibino
# Processing Record 81 of 500 for City: iqaluit
# Processing Record 82 of 500 for City: tuktoyaktuk
# Processing Record 83 of 500 for City: izhma
# Processing Record 84 of 500 for City: vila franca do campo
# Processing Record 85 of 500 for City: chokurdakh
# Processing Record 86 of 500 for City: roma
# Processing Record 87 of 500 for City: arraial do cabo
# Processing Record 88 of 500 for City: portland
# Processing Record 89 of 500 for City: palana
# Processing Record 90 of 500 for City: batagay
# No weather data found for this city: uroteppa, weather server response code:404
# Processing Record 91 of 500 for City: yellowknife
# Processing Record 92 of 500 for City: georgetown
# Processing Record 93 of 500 for City: rajakhera
# Processing Record 94 of 500 for City: castro
# Processing Record 95 of 500 for City: tuatapere
# Processing Record 96 of 500 for City: husavik
# Processing Record 97 of 500 for City: satun
# No weather data found for this city: palabuhanratu, weather server response code:404
# Processing Record 98 of 500 for City: hambantota
# Processing Record 99 of 500 for City: riyadh
# Processing Record 100 of 500 for City: narsaq
# Processing Record 101 of 500 for City: saldanha
# No weather data found for this city: bengkulu, weather server response code:404
# Processing Record 102 of 500 for City: ornskoldsvik
# Processing Record 103 of 500 for City: filingue
# Processing Record 104 of 500 for City: san patricio
# Processing Record 105 of 500 for City: hithadhoo
# Processing Record 106 of 500 for City: jadu
# Processing Record 107 of 500 for City: saint george
# Processing Record 108 of 500 for City: labuhan
# Processing Record 109 of 500 for City: ancud
# Processing Record 110 of 500 for City: san andres
# Processing Record 111 of 500 for City: hilo
# Processing Record 112 of 500 for City: lompoc
# Processing Record 113 of 500 for City: alta floresta
# Processing Record 114 of 500 for City: berdigestyakh
# Processing Record 115 of 500 for City: sendenhorst
# Processing Record 116 of 500 for City: fortuna
# Processing Record 117 of 500 for City: tasiilaq
# Processing Record 118 of 500 for City: shelburne
# Processing Record 119 of 500 for City: irara
# Processing Record 120 of 500 for City: egvekinot
# Processing Record 121 of 500 for City: merauke
# Processing Record 122 of 500 for City: teguldet
# Processing Record 123 of 500 for City: lagoa
# Processing Record 124 of 500 for City: dingle
# Processing Record 125 of 500 for City: atuona
# No weather data found for this city: karamken, weather server response code:404
# Processing Record 126 of 500 for City: garowe
# Processing Record 127 of 500 for City: te anau
# Processing Record 128 of 500 for City: bathsheba
# Processing Record 129 of 500 for City: ambilobe
# No weather data found for this city: muzquiz, weather server response code:404
# Processing Record 130 of 500 for City: rosarito
# Processing Record 131 of 500 for City: nikolskoye
# No weather data found for this city: burica, weather server response code:404
# Processing Record 132 of 500 for City: vintila voda
# Processing Record 133 of 500 for City: san policarpo
# Processing Record 134 of 500 for City: ostersund
# Processing Record 135 of 500 for City: faanui
# Processing Record 136 of 500 for City: sehithwa
# Processing Record 137 of 500 for City: kavali
# Processing Record 138 of 500 for City: natal
# No weather data found for this city: jurado, weather server response code:404
# Processing Record 139 of 500 for City: keti bandar
# Processing Record 140 of 500 for City: muyezerskiy
# No weather data found for this city: berbera, weather server response code:404
# Processing Record 141 of 500 for City: tabuk
# Processing Record 142 of 500 for City: coari
# Processing Record 143 of 500 for City: carnarvon
# Processing Record 144 of 500 for City: srednekolymsk
# Processing Record 145 of 500 for City: shenjiamen
# Processing Record 146 of 500 for City: souillac
# Processing Record 147 of 500 for City: banjar
# No weather data found for this city: tvardica, weather server response code:404
# Processing Record 148 of 500 for City: kuala terengganu
# Processing Record 149 of 500 for City: mnogovershinnyy
# Processing Record 150 of 500 for City: skibotn
# Processing Record 151 of 500 for City: meulaboh
# No weather data found for this city: samusu, weather server response code:404
# Processing Record 152 of 500 for City: erzin
# Processing Record 153 of 500 for City: saint-lo
# Processing Record 154 of 500 for City: barra do bugres
# Processing Record 155 of 500 for City: rocha
# Processing Record 156 of 500 for City: mareeba
# No weather data found for this city: zolotinka, weather server response code:404
# Processing Record 157 of 500 for City: marystown
# Processing Record 158 of 500 for City: lodja
# Processing Record 159 of 500 for City: jalu
# Processing Record 160 of 500 for City: barra da estiva
# No weather data found for this city: tsihombe, weather server response code:404
# Processing Record 161 of 500 for City: santa rosa
# Processing Record 162 of 500 for City: mendoza
# Processing Record 163 of 500 for City: marsa matruh
# Processing Record 164 of 500 for City: khandyga
# Processing Record 165 of 500 for City: padang
# Processing Record 166 of 500 for City: lingao
# Processing Record 167 of 500 for City: lata
# Processing Record 168 of 500 for City: hof
# Processing Record 169 of 500 for City: hearst
# Processing Record 170 of 500 for City: cidreira
# Processing Record 171 of 500 for City: half moon bay
# Processing Record 172 of 500 for City: sorland
# Processing Record 173 of 500 for City: kenai
# Processing Record 174 of 500 for City: flin flon
# Processing Record 175 of 500 for City: thompson
# Processing Record 176 of 500 for City: rio gallegos
# Processing Record 177 of 500 for City: kokopo
# Processing Record 178 of 500 for City: port lincoln
# Processing Record 179 of 500 for City: changji
# Processing Record 180 of 500 for City: ucar
# No weather data found for this city: amderma, weather server response code:404
# Processing Record 181 of 500 for City: much
# Processing Record 182 of 500 for City: chuy
# Processing Record 183 of 500 for City: nouakchott
# Processing Record 184 of 500 for City: new norfolk
# Processing Record 185 of 500 for City: puerto ayora
# Processing Record 186 of 500 for City: byron bay
# Processing Record 187 of 500 for City: xuddur
# Processing Record 188 of 500 for City: lodwar
# Processing Record 189 of 500 for City: sitka
# Processing Record 190 of 500 for City: rancho palos verdes
# Processing Record 191 of 500 for City: goma
# Processing Record 192 of 500 for City: coahuayana
# Processing Record 193 of 500 for City: grindavik
# Processing Record 194 of 500 for City: kruisfontein
# Processing Record 195 of 500 for City: vestmannaeyjar
# Processing Record 196 of 500 for City: eyl
# Processing Record 197 of 500 for City: airai
# Processing Record 198 of 500 for City: gamboula
# No weather data found for this city: kuah, weather server response code:404
# No weather data found for this city: attawapiskat, weather server response code:404
# Processing Record 199 of 500 for City: saskylakh
# Processing Record 200 of 500 for City: prince rupert
# Processing Record 201 of 500 for City: makakilo city
# Processing Record 202 of 500 for City: samarai
# Processing Record 203 of 500 for City: gonbad-e qabus
# Processing Record 204 of 500 for City: lasa
# No weather data found for this city: saleaula, weather server response code:404
# Processing Record 205 of 500 for City: pevek
# Processing Record 206 of 500 for City: port keats
# Processing Record 207 of 500 for City: mount gambier
# No weather data found for this city: grand river south east, weather server response code:404
# Processing Record 208 of 500 for City: rahon
# Processing Record 209 of 500 for City: san cristobal
# Processing Record 210 of 500 for City: quatre cocos
# Processing Record 211 of 500 for City: tias
# Processing Record 212 of 500 for City: planaltina
# Processing Record 213 of 500 for City: yanam
# Processing Record 214 of 500 for City: geraldton
# Processing Record 215 of 500 for City: phalodi
# Processing Record 216 of 500 for City: mizdah
# Processing Record 217 of 500 for City: talara
# Processing Record 218 of 500 for City: aldan
# Processing Record 219 of 500 for City: atar
# Processing Record 220 of 500 for City: roswell
# No weather data found for this city: labutta, weather server response code:404
# Processing Record 221 of 500 for City: upernavik
# Processing Record 222 of 500 for City: bambous virieux
# Processing Record 223 of 500 for City: zhaoyuan
# No weather data found for this city: satitoa, weather server response code:404
# Processing Record 224 of 500 for City: saint-leu
# Processing Record 225 of 500 for City: minot
# Processing Record 226 of 500 for City: hukuntsi
# Processing Record 227 of 500 for City: torata
# Processing Record 228 of 500 for City: conakry
# No weather data found for this city: sentyabrskiy, weather server response code:404
# Processing Record 229 of 500 for City: champerico
# Processing Record 230 of 500 for City: lewistown
# Processing Record 231 of 500 for City: taoudenni
# Processing Record 232 of 500 for City: ciudad bolivar
# Processing Record 233 of 500 for City: lichinga
# Processing Record 234 of 500 for City: caxito
# Processing Record 235 of 500 for City: tondon
# Processing Record 236 of 500 for City: gorgan
# Processing Record 237 of 500 for City: vao
# Processing Record 238 of 500 for City: yerbogachen
# Processing Record 239 of 500 for City: esperance
# Processing Record 240 of 500 for City: strezhevoy
# Processing Record 241 of 500 for City: grand baie
# Processing Record 242 of 500 for City: along
# Processing Record 243 of 500 for City: emerald
# Processing Record 244 of 500 for City: guipavas
# Processing Record 245 of 500 for City: xichang
# Processing Record 246 of 500 for City: kuldur
# Processing Record 247 of 500 for City: kodiak
# Processing Record 248 of 500 for City: cayenne
# Processing Record 249 of 500 for City: segezha
# Processing Record 250 of 500 for City: pisco
# Processing Record 251 of 500 for City: abha
# Processing Record 252 of 500 for City: cabo san lucas
# Processing Record 253 of 500 for City: saint-francois
# No weather data found for this city: nizhneyansk, weather server response code:404
# Processing Record 254 of 500 for City: finnsnes
# Processing Record 255 of 500 for City: verkhnevilyuysk
# Processing Record 256 of 500 for City: salalah
# Processing Record 257 of 500 for City: wajir
# Processing Record 258 of 500 for City: mahebourg
# Processing Record 259 of 500 for City: isangel
# Processing Record 260 of 500 for City: jvari
# Processing Record 261 of 500 for City: jos
# Processing Record 262 of 500 for City: aasiaat
# Processing Record 263 of 500 for City: atasu
# Processing Record 264 of 500 for City: terrace bay
# Processing Record 265 of 500 for City: karari
# Processing Record 266 of 500 for City: mastic beach
# Processing Record 267 of 500 for City: beringovskiy
# Processing Record 268 of 500 for City: babu
# Processing Record 269 of 500 for City: senneterre
# Processing Record 270 of 500 for City: mizan teferi
# Processing Record 271 of 500 for City: sabratah
# Processing Record 272 of 500 for City: berlevag
# Processing Record 273 of 500 for City: lima
# Processing Record 274 of 500 for City: ginda
# Processing Record 275 of 500 for City: purwodadi
# Processing Record 276 of 500 for City: tura
# Processing Record 277 of 500 for City: north vanlaiphai
# Processing Record 278 of 500 for City: iskilip
# Processing Record 279 of 500 for City: mikkeli
# Processing Record 280 of 500 for City: mar del plata
# Processing Record 281 of 500 for City: zlotoryja
# Processing Record 282 of 500 for City: longyearbyen
# Processing Record 283 of 500 for City: frontino
# Processing Record 284 of 500 for City: sardarshahr
# Processing Record 285 of 500 for City: fairbanks
# Processing Record 286 of 500 for City: bang saphan
# Processing Record 287 of 500 for City: puerto princesa
# Processing Record 288 of 500 for City: santa cruz de tenerife
# Processing Record 289 of 500 for City: lebu
# Processing Record 290 of 500 for City: talnakh
# Processing Record 291 of 500 for City: neiafu
# Processing Record 292 of 500 for City: brownsville
# Processing Record 293 of 500 for City: deputatskiy
# Processing Record 294 of 500 for City: hofn
# Processing Record 295 of 500 for City: lorengau
# Processing Record 296 of 500 for City: khor
# Processing Record 297 of 500 for City: juneau
# Processing Record 298 of 500 for City: kidal
# Processing Record 299 of 500 for City: clyde river
# Processing Record 300 of 500 for City: adrar
# Processing Record 301 of 500 for City: daud khel
# No weather data found for this city: ngukurr, weather server response code:404
# Processing Record 302 of 500 for City: boden
# Processing Record 303 of 500 for City: yomou
# Processing Record 304 of 500 for City: hovd
# Processing Record 305 of 500 for City: grand gaube
# Processing Record 306 of 500 for City: gat
# Processing Record 307 of 500 for City: hokitika
# Processing Record 308 of 500 for City: coquimbo
# Processing Record 309 of 500 for City: tezu
# Processing Record 310 of 500 for City: ninghai
# Processing Record 311 of 500 for City: acapulco
# Processing Record 312 of 500 for City: lubuk pakam
# Processing Record 313 of 500 for City: san vicente
# Processing Record 314 of 500 for City: astoria
# Processing Record 315 of 500 for City: lavrentiya
# Processing Record 316 of 500 for City: kaitangata
# No weather data found for this city: zorya, weather server response code:404
# Processing Record 317 of 500 for City: salihli
# No weather data found for this city: dien bien, weather server response code:404
# No weather data found for this city: bolshoy tsaryn, weather server response code:404
# Processing Record 318 of 500 for City: tazmalt
# Processing Record 319 of 500 for City: bhinga
# Processing Record 320 of 500 for City: havoysund
# Processing Record 321 of 500 for City: port hawkesbury
# Processing Record 322 of 500 for City: goderich
# No weather data found for this city: chagda, weather server response code:404
# Processing Record 323 of 500 for City: loiza
# Processing Record 324 of 500 for City: morris
# Processing Record 325 of 500 for City: mentougou
# Processing Record 326 of 500 for City: ixtapa
# Processing Record 327 of 500 for City: mangrol
# Processing Record 328 of 500 for City: vostok
# Processing Record 329 of 500 for City: moerai
# No weather data found for this city: vestbygda, weather server response code:404
# Processing Record 330 of 500 for City: necochea
# Processing Record 331 of 500 for City: banda aceh
# No weather data found for this city: zabinka, weather server response code:404
# Processing Record 332 of 500 for City: pacific grove
# Processing Record 333 of 500 for City: jiangyou
# Processing Record 334 of 500 for City: caravelas
# Processing Record 335 of 500 for City: gobabis
# Processing Record 336 of 500 for City: norman wells
# Processing Record 337 of 500 for City: cam ranh
# Processing Record 338 of 500 for City: ames
# Processing Record 339 of 500 for City: provideniya
# No weather data found for this city: sahrak, weather server response code:404
# Processing Record 340 of 500 for City: livingston
# Processing Record 341 of 500 for City: dongsheng
# Processing Record 342 of 500 for City: petropavlovsk-kamchatskiy
# Processing Record 343 of 500 for City: aktau
# Processing Record 344 of 500 for City: korem
# Processing Record 345 of 500 for City: yatou
# Processing Record 346 of 500 for City: cherdyn
# Processing Record 347 of 500 for City: tual
# Processing Record 348 of 500 for City: borba
# Processing Record 349 of 500 for City: qasigiannguit
# Processing Record 350 of 500 for City: clovis
# Processing Record 351 of 500 for City: ayna
# Processing Record 352 of 500 for City: zhuhai
# Processing Record 353 of 500 for City: la cruz
# Processing Record 354 of 500 for City: fukue
# Processing Record 355 of 500 for City: tobolsk
# Processing Record 356 of 500 for City: newton
# Processing Record 357 of 500 for City: leshukonskoye
# Processing Record 358 of 500 for City: nouadhibou
# Processing Record 359 of 500 for City: nacozari
# No weather data found for this city: manzil jamil, weather server response code:404
# Processing Record 360 of 500 for City: port moresby
# Processing Record 361 of 500 for City: nantucket
# Processing Record 362 of 500 for City: uthal
# No weather data found for this city: akyab, weather server response code:404
# Processing Record 363 of 500 for City: kasangulu
# Processing Record 364 of 500 for City: ossora
# Processing Record 365 of 500 for City: rehau
# Processing Record 366 of 500 for City: aklavik
# Processing Record 367 of 500 for City: aswan
# Processing Record 368 of 500 for City: stromness
# Processing Record 369 of 500 for City: mezen
# Processing Record 370 of 500 for City: hamilton
# Processing Record 371 of 500 for City: rasra
# Processing Record 372 of 500 for City: ilulissat
# Processing Record 373 of 500 for City: utete
# Processing Record 374 of 500 for City: cravo norte
# Processing Record 375 of 500 for City: kushiro
# Processing Record 376 of 500 for City: luderitz
# Processing Record 377 of 500 for City: paamiut
# Processing Record 378 of 500 for City: vanimo
# Processing Record 379 of 500 for City: liverpool
# Processing Record 380 of 500 for City: timra
# Processing Record 381 of 500 for City: sirsilla
# Processing Record 382 of 500 for City: manokwari
# Processing Record 383 of 500 for City: cherskiy
# Processing Record 384 of 500 for City: namatanai
# Processing Record 385 of 500 for City: teahupoo
# Processing Record 386 of 500 for City: beloha
# Processing Record 387 of 500 for City: oudtshoorn
# Processing Record 388 of 500 for City: diu
# Processing Record 389 of 500 for City: klaksvik
# Processing Record 390 of 500 for City: igrim
# Processing Record 391 of 500 for City: kavieng
# Processing Record 392 of 500 for City: klyuchi
# Processing Record 393 of 500 for City: de aar
# Processing Record 394 of 500 for City: kuminskiy
# Processing Record 395 of 500 for City: lethem
# Processing Record 396 of 500 for City: la ronge
# Processing Record 397 of 500 for City: imbituba
# Processing Record 398 of 500 for City: rum
# Processing Record 399 of 500 for City: saint-denis
# No weather data found for this city: kuche, weather server response code:404
# Processing Record 400 of 500 for City: lyngseidet
# Processing Record 401 of 500 for City: chapais
# Processing Record 402 of 500 for City: masterton
# Processing Record 403 of 500 for City: jining
# Processing Record 404 of 500 for City: maxixe
# Processing Record 405 of 500 for City: semey
# No weather data found for this city: yei, weather server response code:404
# No weather data found for this city: cumaribo, weather server response code:404
# Processing Record 406 of 500 for City: taltal
# Processing Record 407 of 500 for City: zhigansk
# Processing Record 408 of 500 for City: magadan
# Processing Record 409 of 500 for City: codrington
# No weather data found for this city: marcona, weather server response code:404
# Processing Record 410 of 500 for City: yulara
# Processing Record 411 of 500 for City: waipawa
# Processing Record 412 of 500 for City: muroto
# Processing Record 413 of 500 for City: ushtobe
# Processing Record 414 of 500 for City: ndioum
# Processing Record 415 of 500 for City: khandbari
# Processing Record 416 of 500 for City: mungaoli
# Processing Record 417 of 500 for City: belle fourche
# Processing Record 418 of 500 for City: umea
# Processing Record 419 of 500 for City: vardo
# Processing Record 420 of 500 for City: vanavara
# Processing Record 421 of 500 for City: salinas
# Processing Record 422 of 500 for City: mabaruma
# Processing Record 423 of 500 for City: machinga
# Processing Record 424 of 500 for City: marsh harbour
# Processing Record 425 of 500 for City: lerwick
# Processing Record 426 of 500 for City: caltagirone
# Processing Record 427 of 500 for City: phalombe
# Processing Record 428 of 500 for City: torbay
# Processing Record 429 of 500 for City: kupang
# Processing Record 430 of 500 for City: parfino
# No weather data found for this city: zlatoustovsk, weather server response code:404
# Processing Record 431 of 500 for City: haapiti
# Processing Record 432 of 500 for City: tacuarembo
# Processing Record 433 of 500 for City: buchanan
# Processing Record 434 of 500 for City: vila velha
# Processing Record 435 of 500 for City: bethel
# Processing Record 436 of 500 for City: bossangoa
# Processing Record 437 of 500 for City: garden city
# Processing Record 438 of 500 for City: yuzhno-sukhokumsk
# Processing Record 439 of 500 for City: manono
# Processing Record 440 of 500 for City: lysychovo
# Processing Record 441 of 500 for City: burnie
# Processing Record 442 of 500 for City: oranjestad
# Processing Record 443 of 500 for City: manggar
# Processing Record 444 of 500 for City: sharya
# No weather data found for this city: hayato, weather server response code:404
# Processing Record 445 of 500 for City: seguela
# Processing Record 446 of 500 for City: cururupu
# Processing Record 447 of 500 for City: panama city
# Processing Record 448 of 500 for City: gayny
# Processing Record 449 of 500 for City: myre
# Processing Record 450 of 500 for City: mocuba
# Processing Record 451 of 500 for City: katsuura
# Processing Record 452 of 500 for City: linqiong
# Processing Record 453 of 500 for City: bandarbeyla
# Processing Record 454 of 500 for City: ferme-neuve
# Processing Record 455 of 500 for City: nemuro
# Processing Record 456 of 500 for City: daru
# Processing Record 457 of 500 for City: upata
# Processing Record 458 of 500 for City: naze
# Processing Record 459 of 500 for City: rundu
# Processing Record 460 of 500 for City: minnetonka
# No weather data found for this city: burkhala, weather server response code:404
# Processing Record 461 of 500 for City: jorpeland
# Processing Record 462 of 500 for City: aras
# Processing Record 463 of 500 for City: kinablangan
# Processing Record 464 of 500 for City: youkounkoun
# Processing Record 465 of 500 for City: vestmanna
# Processing Record 466 of 500 for City: ukiah
# Processing Record 467 of 500 for City: valkeala
# Processing Record 468 of 500 for City: hualmay
# Processing Record 469 of 500 for City: porto velho
# Processing Record 470 of 500 for City: waingapu
# Processing Record 471 of 500 for City: alice springs
# Processing Record 472 of 500 for City: krasnoarmeysk
# No weather data found for this city: dzhusaly, weather server response code:404
# Processing Record 473 of 500 for City: worthington
# Processing Record 474 of 500 for City: yining
# Processing Record 475 of 500 for City: lahad datu
# Processing Record 476 of 500 for City: kulhudhuffushi
# Processing Record 477 of 500 for City: xingcheng
# Processing Record 478 of 500 for City: kardla
# Processing Record 479 of 500 for City: denpasar
# Processing Record 480 of 500 for City: cabatuan
# Processing Record 481 of 500 for City: cap malheureux
# Processing Record 482 of 500 for City: abeche
# Processing Record 483 of 500 for City: takoradi
# Processing Record 484 of 500 for City: davila
# Processing Record 485 of 500 for City: nakusp
# Processing Record 486 of 500 for City: mikhaylovka
# Processing Record 487 of 500 for City: kant
# Processing Record 488 of 500 for City: port-cartier
# Processing Record 489 of 500 for City: seoul
# Processing Record 490 of 500 for City: cabedelo
# Processing Record 491 of 500 for City: kaspiysk
# Processing Record 492 of 500 for City: bocaiuva
# Processing Record 493 of 500 for City: balboa
# No weather data found for this city: temaraia, weather server response code:404
# Processing Record 494 of 500 for City: biak
# Processing Record 495 of 500 for City: golden
# Processing Record 496 of 500 for City: mango
# No weather data found for this city: ascension, weather server response code:404
# Processing Record 497 of 500 for City: bulawayo
# No weather data found for this city: malwan, weather server response code:404
# Processing Record 498 of 500 for City: rorvik
# Processing Record 499 of 500 for City: broken hill
# Processing Record 500 of 500 for City: gigmoto
# stop at limit

# %%
#df.head()
print("Num of elements in each list:")
print(len(foundcities))
print(len(cloudiness))
print(len(country))
print(len(date))
print(len(humidity))
print(len(max_temp))
print(len(wind_speed))
print(len(foundlat))
print(len(foundlong))
# Out:
# Num of elements in each list:
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500

# %%
weather_dict = {
    "City": foundcities,
    "Country": country,
    "Cloudiness": cloudiness,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : foundlat,
    "Lng" : foundlong,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed,
}
weather_data_df = pd.DataFrame(weather_dict)
weather_data_df.head(10)
# Out:
#              City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0  Severo-Kurilsk      RU          92  1552526587        95  50.68  156.12
# 1          Barrow      AR           0  1552526754        76 -38.31  -60.23
# 2      Nanortalik      GL          12  1552526755       100  60.14  -45.24
# 3        Predesti      RO          80  1552526181        85  44.35   23.60
# 4         Kichera      RU          12  1552526755        65  55.93  110.10
# 5          Ialibu      PG          32  1552526755        86  -6.28  143.99
# 6        Hermanus      ZA          20  1552526196        96 -34.42   19.24
# 7       Busselton      AU           0  1552526462        45 -33.64  115.35
# 8           Vaini      IN           0  1552521600        49  15.34   74.49
# 9           Khash      IR           0  1552526756        73  28.22   61.21
#
#    Max Temp  Wind Speed
# 0     30.89       20.96
# 1     58.07        9.44
# 2     25.89       27.89
# 3     39.00        8.05
# 4      4.02        2.73
# 5     62.52        1.95
# 6     64.99        3.06
# 7     70.00       14.14
# 8     69.80        2.06
# 9     29.04        2.73

# %%
weather_data_df.to_csv("output_data/city_weather.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
def plotvslatitude(inputlist):
    
    if inputlist == "Max Temp":
        ylabeltxt = "Max Temperature (Farenheit)"
        titlesub = "Max Temperature"
        filenamesub = "MaxTemperature"
    elif inputlist == "Humidity":
        titlesub = inputlist
        ylabeltxt = "Humidity (%)"
        filenamesub = "Humidity"
    elif inputlist == "Cloudiness":
        titlesub = inputlist
        ylabeltxt = "Cloudiness (%)"
        filenamesub = "Cloudiness"
    elif inputlist == "Wind Speed":
        titlesub = inputlist
        ylabeltxt = "Wind Speed (mph)"
        filenamesub = "WindSpeed"
    
    
    
    # Build a scatter plot for each data type
    plt.scatter(weather_data_df["Lat"], weather_data_df[inputlist], marker="o")

    # Incorporate the other graph properties
    todaydate = now.strftime("%m/%d/%Y")
    plt.title("City Latitude vs " + titlesub + " (" + todaydate + ")")
    plt.ylabel(ylabeltxt)
    plt.xlabel("Latitude")
    plt.grid(True)

    # Save the figure
    plt.savefig("output_data/LatitudeBy" + filenamesub + "ScatterPlotWorldCities.png")

    # Show plot
    plt.show()

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plotvslatitude("Max Temp")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plotvslatitude("Humidity")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plotvslatitude("Cloudiness")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plotvslatitude("Wind Speed")
